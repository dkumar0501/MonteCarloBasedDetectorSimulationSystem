# %%
import pandas as pd, seaborn as sns, matplotlib.pyplot as plt

df = pd.read_csv("../data/energy_deposition.csv")
sns.boxplot(x="Material", y="DamageIndex", data=df)
plt.title("Radiation Damage Distribution by Material")
plt.show()
